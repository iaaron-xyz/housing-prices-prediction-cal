# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Import data

# %%
data_path = "data/population.csv"
df = pd.read_csv(data_path, sep=";")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147043 entries, 0 to 147042
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Geoname ID               147043 non-null  int64
#  1   Name                     147042 non-null  object
#  2   ASCII Name               147041 non-null  object
#  3   Alternate Names          120039 non-null  object
#  4   Feature Class            147043 non-null  object
#  5   Feature Code             147043 non-null  object
#  6   Country Code             146966 non-null  object
#  7   Country name EN          146835 non-null  object
#  8   Country Code 2           80 non-null      object
#  9   Admin1 Code              147017 non-null  object
#  10  Admin2 Code              125981 non-null  object
#  11  Admin3 Code              74494 non-null   object
#  12  Admin4 Code              20609 non-null   object
# ...

# %%
df.head()
# Out:
#    Geoname ID       Name ASCII Name  \
# 0     1799869    Nanning    Nanning
# 1     1806988     Huayin     Huayin
# 2     1815494   Changxin   Changxin
# 3     1921372  Dalianwan  Dalianwan
# 4     1922014   Wuyishan   Wuyishan
#
#                                      Alternate Names Feature Class  \
# 0  Lam-leng-chhi,Lâm-lêng-chhī,NNG,Nam Ninh,Nam-n...             P
# 1  Hua-yin-hsien,Hua-yin-hsien-ch'eng,Hua-yin-hsi...             P
# 2  Ch'ang-hsin-p'u,Changxin,Changxingpu,Ch’ang-hs...             P
# 3                                                NaN             P
# 4  Bú-î-soaⁿ-chhī,Ciudad de Wuyishan,U-i-sang-che...             P
#
#   Feature Code Country Code Country name EN Country Code 2 Admin1 Code  \
# 0         PPLA           CN           China            NaN          16
# 1          PPL           CN           China            NaN          26
# 2          PPL           CN           China            NaN          21
# ...

# %% [markdown]
# ## Clean the data

# %% [markdown]
# The cleaning will consist in:
# - Leave only relevant columns, removing the rest. The relevant columns are:
#     - `Geoname ID`
#     - `Name`
#     - `Country Code`
#     - `Country Name EN`
#     - `Population`
#     - `Label EN`
#     - `Coordinates`
# - Split `Coordinates` into `Latitude` and `Longitude`
#
# Depending on the further column explorations, the number of relevant columns could decrease.

# %% [markdown]
# ### Remove the non relevant columns

# %%
df_viz = df.drop(columns=[
                    'ASCII Name',
                    'Alternate Names',
                    'Feature Class',
                    'Feature Code',
                    'Country Code 2',
                    'Admin1 Code',
                    'Admin2 Code',
                    'Admin3 Code',
                    'Admin4 Code',
                    'Elevation',
                    'DIgital Elevation Model',
                    'Timezone',
                    'Modification date',
                    'LABEL EN']
                )
df_viz.head()
# Out:
#    Geoname ID       Name Country Code Country name EN  Population  \
# 0     1799869    Nanning           CN           China     3839800
# 1     1806988     Huayin           CN           China      242488
# 2     1815494   Changxin           CN           China       25095
# 3     1921372  Dalianwan           CN           China       55841
# 4     1922014   Wuyishan           CN           China      137133
#
#            Coordinates
# 0  22.81667, 108.31667
# 1  34.56528, 110.06639
# 2  38.67472, 106.32972
# 3    39.02861, 121.695
# 4  27.75995, 118.03066

# %% [markdown]
# ### Split coordinates column into Longitude and Latitude
